# %% [markdown]
# <a href="https://colab.research.google.com/github/tmedeirosb/streamlit-pycaret-ca/blob/main/modelo_pycaret_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exemplo de uso do pycaret para o dataset Câncer

# %%
#!pip install pycaret

# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.3.1'

# %%
# loading sample dataset from pycaret dataset module
from pycaret.datasets import get_data

data = get_data('cancer')
print("Número de Atributos:", data.shape[1])
print("Preview dos Dados:\n", data.head())
# Out:
#    Class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0      0    5          1           1          1          2          1       3
# 1      0    5          4           4          5          7         10       3
# 2      0    3          1           1          1          2          2       3
# 3      0    6          8           8          1          3          4       3
# 4      0    4          1           1          3          2          1       3
#
#    breast-quad  irradiat
# 0            1         1
# 1            2         1
# 2            1         1
# 3            7         1
# 4            1         1
# Número de Atributos: 10
# Preview dos Dados:
#     Class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0      0    5          1           1          1          2          1       3
# 1      0    5          4           4          5          7         10       3
# ...

# %%
# import pycaret classification and init setup
from pycaret.classification import *
s = setup(data, target = 'Class', session_id = 123)
# Out:
# <style type="text/css">
# #T_09335_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_09335" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09335_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_09335_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09335_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09335_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_09335_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_09335_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09335_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_09335_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_09335_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_13d37 th {
#   text-align: left;
# }
# ...

# %%
# plot confusion matrix
plot_model(best, plot = 'confusion_matrix')

# %%
# plot AUC
plot_model(best, plot = 'auc')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# predict on test set
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_848fb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_848fb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_848fb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_848fb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_848fb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_848fb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_848fb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_848fb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_848fb_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_848fb_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# show predictions df
holdout_pred.head()
# Out:
#      age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 265    7          2           4          1          3          4       3
# 394    2          3           2          2          2          2       3
# 337    2          1           1          1          2          1       3
# 66     8          3           8          3          4          9       8
# 246    9         10          10          1         10          8       3
#
#      breast-quad  irradiat  Class  prediction_label  prediction_score
# 265            3         1      1                 1              0.61
# 394            1         1      0                 0              0.87
# 337            1         1      0                 0              1.00
# 66             9         8      1                 1              0.93
# 246            3         1      1                 1              0.86

# %%
# save pipeline
save_model(best, 'cancer_baseline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'menopause', 'tumor-size',
#                                               'inv-nodes', 'node-caps',
#                                               'deg-malig', 'breast',
#                                               'breast-quad', 'irradiat'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
# ...

# %%
# tune hyperparameters of dt
tuned_dt = tune_model(best)
# Out:
# <style type="text/css">
# #T_90ea4_row10_col0, #T_90ea4_row10_col1, #T_90ea4_row10_col2, #T_90ea4_row10_col3, #T_90ea4_row10_col4, #T_90ea4_row10_col5, #T_90ea4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_90ea4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90ea4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_90ea4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_90ea4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_90ea4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_90ea4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_90ea4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_90ea4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_dt
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='gini',
#                      max_depth=6, max_features='log2', max_leaf_nodes=None,
#                      max_samples=None, min_impurity_decrease=0.001,
#                      min_samples_leaf=6, min_samples_split=9,
#                      min_weight_fraction_leaf=0.0, monotonic_cst=None,
#                      n_estimators=190, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)

# %%
# save pipeline
save_model(tuned_dt, 'cancer_tune')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'menopause', 'tumor-size',
#                                               'inv-nodes', 'node-caps',
#                                               'deg-malig', 'breast',
#                                               'breast-quad', 'irradiat'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
# ...

# %%
#!pip install pycaret[full]
#!pip install shap

# %%
# interpret summary model
interpret_model(tuned_dt, plot = 'summary')

# %%
final_best = finalize_model(tuned_dt)

# %%
# save model
save_model(final_best, 'final_cancer')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'menopause', 'tumor-size',
#                                               'inv-nodes', 'node-caps',
#                                               'deg-malig', 'breast',
#                                               'breast-quad', 'irradiat'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
# ...
